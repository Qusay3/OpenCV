# %% [markdown]
# Image resizing using OpenCV libarary

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Reading the image

# %%
import requests
url = 'https://images7.alphacoders.com/404/404193.jpg'
r = requests.get(url)
with open('image.jpg', 'wb') as f:
    f.write(r.content)

# %%
image = cv2.imread('image.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(image[:, :, ::-1])

# %%
height, width = image.shape[:2]
aspect_ratio = width / height
print(f"Height: {height}")
print(f"Width: {width}")
print(f"Aspect Ratio: {aspect_ratio}")
# Out:
# Height: 1080
# Width: 1920
# Aspect Ratio: 1.7777777777777777

# %% [markdown]
# Resizing the image ( make it small )

# %%
down_width = 300
down_height = 200
down_points = (down_width, down_height)
resized_down = cv2.resize(image, down_points, interpolation = cv2.INTER_LINEAR)
#plt.imshow(resized_down)

# %% [markdown]
# Resizing the image ( make it large )

# %%
up_width = 600
up_height = 400
up_points = (up_width, up_height)
resized_up = cv2.resize(image, up_points, interpolation = cv2.INTER_LINEAR)

# %%
plt.figure(figsize=(15, 15))
plt.subplot(131); plt.imshow(image[:, :, ::-1]); plt.title('Original Image\nAspect Ratio: 1.7')
plt.subplot(132); plt.imshow(resized_up[:, :, ::-1]); plt.title('Scaled up Image\nAspect Ratio: 1.7')
plt.subplot(133); plt.imshow(resized_down[:, :, ::-1]); plt.title('Scaled down Image\nAspect Ratio: 1.5')
# Out:
# Text(0.5, 1.0, 'Scaled down Image\nAspect Ratio: 1.5')

# %% [markdown]
# Specify scaling factor

# %%
#scaling up dactor
scale_up_x = 1.5
scale_up_y = 1.5

#scaleing down factor
scale_down = 0.5

scaled_f_down = cv2.resize(image, None, fx=scale_down, fy=scale_down, interpolation = cv2.INTER_LINEAR)
scaled_f_up = cv2.resize(image, None, fx=scale_up_x, fy=scale_up_y, interpolation = cv2.INTER_LINEAR)

# %%
# display the image
plt.figure(figsize=(15, 15))
plt.subplot(121); plt.imshow(scaled_f_down[..., ::-1])
plt.title('Scaled down Image, size = {}'.format(scaled_f_down.shape[:2]))
plt.subplot(122); plt.imshow(scaled_f_up[..., ::-1])
plt.title('Scaled up Image, size = {}'.format(scaled_f_up.shape[:2]))
# Out:
# Text(0.5, 1.0, 'Scaled up Image, size = (1620, 2880)')
